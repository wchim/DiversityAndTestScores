# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('17-18DemoMath.csv')
df.head()
# Out:
#       DBN                     School Name  Number Tested  Mean Scale Score  \
# 0  01M015       P.S. 015 Roberto Clemente             67               607
# 1  01M019             P.S. 019 Asher Levy             89               603
# 2  01M020            P.S. 020 Anna Silver            212               593
# 3  01M034  P.S. 034 Franklin D. Roosevelt            221               588
# 4  01M063       The STAR Academy - P.S.63             64               602
#
#    Level 1 #  Level 1 %  Level 2 #  Level 2 %  Level 3 #  Level 3 %  ...  \
# 0          8       11.9         20       29.9         22       32.8  ...
# 1         21       23.6         16       18.0         26       29.2  ...
# 2         88       41.5         49       23.1         38       17.9  ...
# 3        121       54.8         65       29.4         24       10.9  ...
# 4         12       18.8         15       23.4         24       37.5  ...
#
#    % Others  # White  % White  # Students with Disabilities  \
# ...

# %%
df.columns
# Out:
# Index(['DBN', 'School Name', 'Number Tested', 'Mean Scale Score', 'Level 1 #',
#        'Level 1 %', 'Level 2 #', 'Level 2 %', 'Level 3 #', 'Level 3 %',
#        'Level 4 #', 'Level 4 %', 'Level 3+4 #', 'Level 3+4 %',
#        'Total Enrollment', 'Grade PK (Half Day & Full Day)', 'Grade K',
#        'Grade 1', 'Grade 2', 'Grade 3', 'Grade 4', 'Grade 5', 'Grade 6',
#        'Grade 7', 'Grade 8', 'Grade 9', 'Grade 10', 'Grade 11', 'Grade 12',
#        '# Female', '% Female', '# Male', '% Male', '# Asian', '% Asian',
#        '# Black', '% Black', '# Hispanic', '% Hispanic', '# Others',
#        '% Others', '# White', '% White', '# Students with Disabilities',
#        '% Students with Disabilities', '# English Language Learners',
#        '% English Language Learners', '# Poverty', '% Poverty',
#        'Economic Need Index'],
#       dtype='object')

# %%
df.shape
# Out:
# (1105, 50)

# %%
sns.barplot(x=df['Total Enrollment'].sort_values(ascending=False).head(10),
            y=df.sort_values('Total Enrollment', ascending=False)['School Name'].head(10),
            color='gray',
            alpha=1,)
    
plt.title("Top 10 Schools by Total Student Enrollment during 2017-18 School Year")
plt.xlabel("Total Student Enrollment")
plt.ylabel("School Name")
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,5))
sns.set_style("whitegrid")

weights_m = np.ones_like(np.array(df['% Male']))/float(len(np.array(df['% Male'])))
axs[0].hist(df['% Male'], 
            weights=weights_m,
            bins=100,
            color='lightblue')

weights_f = np.ones_like(np.array(df['% Female']))/float(len(np.array(df['% Female'])))
axs[1].hist(df['% Female'],
            weights=weights_f,
            bins=100,
            color='pink')

fig.suptitle("Gender Distribution Across 1105 Schools During the 2017-18 School Year")
axs[0].legend(["Male"])
axs[0].set_xlabel("Percentage of Male Students")
axs[0].set_ylabel("Percentage of Schools")
axs[1].legend(["Female"])
axs[1].set_xlabel("Percentage of Female Students")
fig.show()
# Out:
# C:\Users\17189\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
fig, axs = plt.subplots(2, 2, sharex = True, sharey = True, figsize=(10,10))
sns.set_style("whitegrid")

weights_a = np.ones_like(np.array(df['% Asian']))/float(len(np.array(df['% Asian'])))
axs[0][0].hist(df['% Asian'],
               weights=weights_a,
               bins=100,
               color='orange')

weights_b = np.ones_like(np.array(df['% Black']))/float(len(np.array(df['% Black'])))
axs[0][1].hist(df['% Black'],
               weights=weights_b,
               bins=100,
               color='purple')

weights_h = np.ones_like(np.array(df['% Hispanic']))/float(len(np.array(df['% Hispanic'])))
axs[1][0].hist(df['% Hispanic'],
               weights=weights_h,
               bins=100,
               color='green')

weights_w = np.ones_like(np.array(df['% White']))/float(len(np.array(df['% White'])))
axs[1][1].hist(df['% White'],
               weights=weights_w,
               bins=100,
               color='gray')

fig.suptitle("Ethnicity Distribution Across 1105 Schools During the 2017-18 School Year")
fig.text(0.5, 0.04, "Percentage of Students by Ethnicity", ha="center")
fig.text(0.04, 0.5, "Percentage of Schools", va="center", rotation="vertical")

axs[0][0].legend(["Asian"])
axs[0][0].set_xlabel("")
axs[0][1].legend(["Black"])
axs[0][1].set_xlabel("")
axs[1][0].legend(["Hispanic"])
axs[1][0].set_xlabel("")
axs[1][1].legend(["White"])
fig.show()
# Out:
# C:\Users\17189\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
